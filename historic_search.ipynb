# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import TranscriptsDisabled, NoTranscriptFound, VideoUnavailable
import os
import googleapiclient.discovery
import googleapiclient.errors
from google.oauth2 import service_account
import json
import datetime
import ipywidgets as widgets
import pandas as pd

# %%
# globals
filename = 'speeches.lg.json'

SCOPES = ["https://www.googleapis.com/auth/youtube.readonly"]
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

api_service_name = "youtube"
api_version = "v3"
service_account_file = "service_account.json"

# format date
def f_date(in_date): 
    return in_date.isoformat()#+'+04:00' #+4:00 is needed to set to EST

# run a youtube search over a date range
def run_search(query, start_date, end_date, page=None):
    request = youtube.search().list(
        part="snippet",
        maxResults=50,
        pageToken=page,
        publishedAfter=f_date(start_date),
        publishedBefore=f_date(end_date),
        q=query,
        topicId="/m/05qt0",
        type="video",
        videoCaption="videoCaptionUnspecified",
        videoDuration="long"
    )
    return request.execute()

# match the json structure from "create_records.py"
def build_video_details(videoId, candidate):
    captions = None
    
    request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=videoId
        )
    response = request.execute()
    
    try:
        captions = YouTubeTranscriptApi.get_transcript(videoId)
    except TranscriptsDisabled:
        print("Transcripts disabled for video: %s" % videoId)
    except NoTranscriptFound:
        print("No transcript found for video: %s" % videoId)
    except VideoUnavailable:
        print("Video no longer available: %s" % videoId)
    
    response['items'][0]['candidate'] = candidate
    response['items'][0]['captions'] = captions
    
    return response

# %%
# Get credentials and create an API client
credentials = service_account.Credentials.from_service_account_file(
        service_account_file, scopes=SCOPES)
youtube = googleapiclient.discovery.build(
        api_service_name, api_version, credentials=credentials)

# %%
candidates = [
    {"person": "biden",
     "q": '"biden" speech|remarks|stream -trump'},
    {"person": "trump",
     "q": '"trump" speech|remarks|stream -biden -melania'},
    {"person": "harris",
     "q": '"kamala" "harris" speech|remarks|stream'},
    {"person": "pence",
     "q": 'mike "pence" speech|remarks|stream'}
]

# %%
# setup before loops - set this date to wherever we left off last time
start_date = datetime.datetime(2020, 7, 29, tzinfo=datetime.timezone.utc)
ci = 3 # candidate index

# create blank dataframe to start
df = pd.DataFrame(columns=['id','person','title','date'])

# %%
# re-run from here

if ci==3:
    # reset candidate loop, go back 1 week
    ci=0
    # week loop
    end_date = start_date
    start_date = end_date - datetime.timedelta(days=7)
else:
    ci = ci + 1
    
# candidate loop
person = candidates[ci]['person']
query = candidates[ci]['q']

print("Candidate: " + person)
print("Week starting: {}".format(start_date))

# run a search on this candidate for this week
response = run_search(query, start_date, end_date)
titles = [[i['id']['videoId'],i['snippet']['title']] for i in response['items']]
sm = widgets.SelectMultiple(
    options=[t[0]+' '+t[1] for t in titles],
    #value=,
    #rows=10,
    description='Speeches',
    disabled=False,
    layout=widgets.Layout(width='90%', height='800px')
)
print("Select the speeches to keep, then run the next block")
display(sm)
# Out:
# Candidate: pence
# Week starting: 2020-07-29 00:00:00+00:00
# Select the speeches to keep, then run the next block
# SelectMultiple(description='Speeches', layout=Layout(height='800px', width='90%'), options=('GXp7SZQSHuc Vice …

# %%
ids = [t[0] for t in titles if t[0]+' '+t[1] in (sm.value)]
titles = [t[1] for t in titles if t[0] in ids]
dates = [i['snippet']['publishedAt'][:10] for i in response['items'] if i['id']['videoId'] in ids]
persons = [person for i in ids]
df = df.append(pd.DataFrame({"id":ids, "person":persons, "title":titles, "date":dates}))
print("Added {} items".format(len(ids)))
# end loop - go back and run the previous block
# Out:
# Added 8 items

# %%
df
# Out:
#              id person                                              title  \
# 0   bduvZIp6UCo  biden        Joe Biden remarks on the latest jobs report
# 1   cuuJ9czNT0g  biden  LIVE: Presidential candidate Joe Biden deliver...
# 2   DubLPc_l0Mc  biden  Democratic presidential nominee Joe Biden deli...
# 3   uBigQgyIPkE  biden  Joe Biden&#39;s full campaign speech HD 8/31/2020
# 4   3BImHVEOY6g  biden  Joe Biden Delivers Remarks Democratic presiden...
# ..          ...    ...                                                ...
# 3   00CXl6jqZC4  pence  Vice President Pence Delivers Remarks on the T...
# 4   k8kYwhNn3L8  pence  WATCH- Vice President Pence at Pennsylvania -C...
# 5   VyZqo-PZsAo  pence  WATCH: Vice President Pence at Pennsylvania &q...
# 6   rArvMOM80HE  pence  Vice President Mike Pence speaks at a Cops for...
# 7   F8HwFvwAkXg  pence  Vice President Pence Delivers Remarks on the T...
#
#           date
# 0   2020-09-04
# 1   2020-09-04
# 2   2020-09-02
# 3   2020-09-03
# 4   2020-09-02
# ..         ...
# 3   2020-07-31
# 4   2020-07-30
# 5   2020-07-30
# 6   2020-07-30
# 7   2020-07-30
#
# [160 rows x 4 columns]

# %%
#Read in existing JSON, or create if JSON does not exist
if os.path.isfile(filename):
    speeches=json.load(open(filename))
else:
    speeches=[]

# %%
for row in df.iterrows():
    r = row[1] # actual row
    print('Video {}'.format(r['id']))
    speeches.append(build_video_details(r['id'], r['person']))
# Out:
# Video bduvZIp6UCo
# Video cuuJ9czNT0g
# Video DubLPc_l0Mc
# Video uBigQgyIPkE
# Video 3BImHVEOY6g
# Video FKsNEsEPxTI
# Video TCwxRU1ypSE
# Video -kA8QjQItGU
# Video YNMQzLnkJ94
# Video HGwE2LNWj4o
# Video c0lt0Cf2kQc
# Video zddirtktOgA
# Transcripts disabled for video: zddirtktOgA
# Video Jtm2HOUljtg
# Video 8e4XufaznSo
# Video YsrBhCXhlBY
# Video xfLUAJ2DiM0
# Video eAM948gYPe8
# Transcripts disabled for video: eAM948gYPe8
# Video 4rSKWIyOYas
# Transcripts disabled for video: 4rSKWIyOYas
# Video eBVEf0ly6G8
# Video A5oJSJjFk2A
# Video vXB_30_3Je8
# Video LcpPA2C4mew
# Video nUGjYs3YTes
# Transcripts disabled for video: nUGjYs3YTes
# Video 2zCEP4tkDWQ
# Video V9HgTko9y3U
# Video oIBl19NxLtU
# Video 1-7mom0W3gY
# Video TKXdcfqkXDc
# Video Gg0Uo6EKflk
# Video a2ET_oiFS5s
# Video Kirmh-y-fVU
# Transcripts disabled for video: Kirmh-y-fVU
# Video QwBkleZI8TQ
# Video naDuBCBaaz0
# Video QVst_8O8YEw
# Video -VVIkXMR2I4
# Video Rp2reLIym9I
# Transcripts disabled for video: Rp2reLIym9I
# Video E9XJB5AWXLs
# Video f2CQn4BGD0U
# Video 4JcGu49XONM
# Video oCZ-Z5F53mw
# Video sF4IJJYB0sE
# Video A1S0TSPJjv4
# Video 983CUgs-yeo
# Video nDoGviLokdY
# Video ydIx-tdwIWA
# Video w92Z9zhlyyg
# Video aRSmzPH4Roc
# Video tarm0TFUrl8
# Video ED4tLsYD_UY
# Transcripts disabled for video: ED4tLsYD_UY
# Video K97JQtF7k-Y
# Video dq1Dxqhx-Ew
# Video PEgcKDSJsbk
# Transcripts disabled for video: PEgcKDSJsbk
# Video q3px3Y3jV_c
# Video 8eUex7-C1ZM
# Video Og8PLfNwNOw
# Video fIHWeSBI9o8
# Video oDbrvKNMLmo
# Video jOQyEziP0l4
# Video HaVgBGJ8eqE
# Video jS7f3WJ5Qxg
# Video bKgMG-tfOVc
# Transcripts disabled for video: bKgMG-tfOVc
# Video RIGY7M7yzvE
# Video phExlTrOI3M
# Video Pks8WrpOnh8
# Transcripts disabled for video: Pks8WrpOnh8
# Video n5fTzsY8Aeo
# Video RNmJeqEyBzU
# Transcripts disabled for video: RNmJeqEyBzU
# Video T1dQoF0bgOE
# Video ZNv0PptlN5Y
# Transcripts disabled for video: ZNv0PptlN5Y
# Video W0rDjEHHuf0
# Video fHFc4Wlo-ZU
# Video H1_iSMi8TjQ
# Video B-PVE1bWcO0
# Video yKdQ2TOAE40
# Video abn3OjrYLR8
# Video KrOurqQ7fWk
# Video CiJHZ_v6NQk
# Video 7a4ekTZfw3o
# Video BdhG1w-_ooU
# Video hPupLCwrDrs
# Video _doBqzH0dco
# Video kii4mJ0wSXE
# Video 2GC_iw5ySKs
# Video B0PUMGkdabA
# Video UBga6RZ5b-g
# Video PzedrN-PqqY
# Video DUctjkieLM8
# Video HZjwi39D7hY
# Video eGoosymzHmE
# Video lZ9a0hgjCaI
# Video fTIP1QqftZc
# Transcripts disabled for video: fTIP1QqftZc
# Video ThKsSRycppE
# Video n1MjW2dEHqo
# Video pabV-hEiYwY
# Video mTdNpHld7M4
# Video rr-lh_TegUY
# Video 12bYkx2cNWg
# Video xLoKJ0LLNpA
# Video H0e_Tonhyiw
# Video UqW-_Hpx5ec
# Transcripts disabled for video: UqW-_Hpx5ec
# Video jw-zyHir_nc
# Video _mtFXn0g5sk
# Video S-ziADbvAls
# Transcripts disabled for video: S-ziADbvAls
# Video sNaWPhzCcoo
# Video Z_2d4EqBNcU
# Transcripts disabled for video: Z_2d4EqBNcU
# Video CyIi8GYrknk
# Video otw4WOpK51A
# Transcripts disabled for video: otw4WOpK51A
# Video vfcqwDKwcJE
# Transcripts disabled for video: vfcqwDKwcJE
# Video RUe4UD0_b9Q
# Video yB5DcRrlfVA
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-c8d271047514> in <module>
#       2     r = row[1] # actual row
#       3     print('Video {}'.format(r['id']))
# ----> 4     speeches.append(build_video_details(r['id'], r['person']))
#       5
#
# <ipython-input-160-bcfd221f7061> in build_video_details(videoId, candidate)
#      10
#      11     try:
# ---> 12         captions = YouTubeTranscriptApi.get_transcript(videoId)
#      13     except TranscriptsDisabled:
#      14         print("Transcripts disabled for video: %s" % videoId)
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/youtube_transcript_api/_api.py in get_transcript(cls, video_id, languages, proxies, cookies)
#     126         :rtype [{'text': str, 'start': float, 'end': float}]:
#     127         """
# --> 128         return cls.list_transcripts(video_id, proxies, cookies).find_transcript(languages).fetch()
#     129
#     130     @classmethod
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/youtube_transcript_api/_api.py in list_transcripts(cls, video_id, proxies, cookies)
#      68                 http_client.cookies = cls._load_cookies(cookies, video_id)
#      69             http_client.proxies = proxies if proxies else {}
# ---> 70             return TranscriptListFetcher(http_client).fetch(video_id)
#      71
#      72     @classmethod
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/youtube_transcript_api/_transcripts.py in fetch(self, video_id)
#      32             self._http_client,
#      33             video_id,
# ---> 34             self._extract_captions_json(self._fetch_html(video_id), video_id)
#      35         )
#      36
#
# ~/anaconda3/envs/python38/lib/python3.8/site-packages/youtube_transcript_api/_transcripts.py in _extract_captions_json(self, html, video_id)
#      44             raise TranscriptsDisabled(video_id)
#      45
# ---> 46         captions_json = json.loads(
#      47             splitted_html[1].split(',"videoDetails')[0].replace('\n', '')
#      48         )['playerCaptionsTracklistRenderer']
#
# KeyError: 'playerCaptionsTracklistRenderer'

# %%
len(speeches)
# Out:
# 108

# %%
# write json
with open(filename, 'w') as outfile:
     json.dump(speeches, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'ZySrvTkejIiwFF0_spKeF98XZ3Y',
#  'id': {'kind': 'youtube#video', 'videoId': 'GXp7SZQSHuc'},
#  'snippet': {'publishedAt': '2020-07-30T20:46:34Z',
#   'channelId': 'UCYxRlFDqcWM4y7FfpiAN3KQ',
#   'title': 'Vice President Pence Delivers Remarks on the Trump Administration&#39;s Pro-Growth Economic Policies',
#   'description': 'Somerset, PA.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GXp7SZQSHuc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/GXp7SZQSHuc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/GXp7SZQSHuc/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'The White House',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2020-07-30T20:46:34Z'}}

# %%
[i['id']['videoId'] for i in response['items']]
# Out:
# ['GXp7SZQSHuc',
#  'gnCNlvwnfGI',
#  'NMTcCKIlIQk',
#  '00CXl6jqZC4',
#  'TcUL15cXbq4',
#  'k8kYwhNn3L8',
#  'pHJ3Am5bi6E',
#  'Z0sI26VIeQc',
#  '5Jp6zDpsppk',
#  'VyZqo-PZsAo',
#  'rArvMOM80HE',
#  'qdbqDiv9VGI',
#  'uuEIeL_Zdpc',
#  'W-ZRga3an70',
#  'IQZAIXR6uGQ',
#  'F8HwFvwAkXg',
#  'HnO2jic0u94',
#  'mQxq9jEbaVo',
#  'ioIZYDbWdP8',
#  'rV3NZ87JKkU',
#  'gLYMkWLvCVc',
#  'HeyQ6y8j9hg',
#  'BBNP90un4Yw',
#  'vBbDFWe2qHE',
#  'AKBoZO-N9qw',
#  '5c-cMFGj7z8',
#  '24bww07I3n0',
#  'saEsOx_8qsc',
#  'mQrpTwmGCA4',
#  'RQVSs2OBXAI',
#  '81O4drevH4A',
#  'Tl06VsfqgQI',
#  '_lHW16SfTEM',
#  'c1fspfF3VBE',
#  'm8KJfcd-GsE',
#  'zaaTZkqsaxY',
#  'm9pB8Qdqixw',
#  'UZNS1cD4UE0',
#  'Y4q5cOyoFMs',
#  'Mn1JQNq0rlg',
#  'ZoUCpLjYkL0',
#  'YFXvqILn7HY',
#  '8YJXpPsziBA',
#  'pKiiYjQkZ78',
#  '5DzO1dLZkow',
#  'FBM9ZbgYPzU',
#  'eaStjvlVdww',
#  'M8Jo0F7YJfQ',
#  'jajFEfyQgnA',
#  '-1jDj0fAzTk']
